# %% [markdown]
# # **Part I: Data Preprocessing**
#
# ## Goal: Familiarize with the World Development Indicators dataset and reshape it into panel data.
# ## Panel data, also known as longitudinal data or cross-sectional time series data, is a type of data that combines both cross-sectional and time series dimensions.
# ### What does panel data looks like?
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/d0129c6f110d4f49a62ed9529a6eee1906d0eb75f6464f049ab0d7573d5ab3d6)

# %% [markdown]
# # **World Bank World Development Indicators WDI dataset**
#
# >The World Development Indicators is a compilation of relevant, high-quality, and internationally comparable statistics about global development and the fight against poverty. The database contains 1,400 time series indicators for 217 economies and more than 40 country groups, with data for many indicators going back more than 50 years.
#
#
# >https://datatopics.worldbank.org/world-development-indicators/

# %% [markdown]
# # Q1 How to read the CSV file and name the dataframe as df?

# %%
import pandas as pd

df = pd.read_csv('/home/aistudio/data/data259984/WDIData.csv')

### If the file format is xlsx, please use read_excel().

df
# Out:
#                        Country Name Country Code  \
# 0       Africa Eastern and Southern          AFE
# 1       Africa Eastern and Southern          AFE
# 2       Africa Eastern and Southern          AFE
# 3       Africa Eastern and Southern          AFE
# 4       Africa Eastern and Southern          AFE
# ...                             ...          ...
# 393143                     Zimbabwe          ZWE
# 393144                     Zimbabwe          ZWE
# 393145                     Zimbabwe          ZWE
# 393146                     Zimbabwe          ZWE
# 393147                     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 0       Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3                 Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4       Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...                                                   ...                ...
# 393143  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 393144  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 393145  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 393146  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 393147  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#         1960  1961  1962  1963  1964  1965  ...          2014          2015  \
# 0        NaN   NaN   NaN   NaN   NaN   NaN  ...     17.392349     17.892005
# 1        NaN   NaN   NaN   NaN   NaN   NaN  ...      6.720331      7.015917
# 2        NaN   NaN   NaN   NaN   NaN   NaN  ...     38.184152     38.543180
# 3        NaN   NaN   NaN   NaN   NaN   NaN  ...     31.859257     33.903515
# 4        NaN   NaN   NaN   NaN   NaN   NaN  ...     17.623956     16.516633
# ...      ...   ...   ...   ...   ...   ...  ...           ...           ...
# 393143   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN     14.500000
# 393144   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN      3.700000
# 393145   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN     32.400000
# 393146   NaN   NaN   NaN   NaN   NaN   NaN  ...     59.400000     59.500000
# 393147   NaN   NaN   NaN   NaN   NaN   NaN  ...  19000.000000  17000.000000
#
#                 2016          2017          2018         2019         2020  \
# 0          18.359993     18.795151     19.295176    19.788156    20.279599
# 1           7.281390      7.513673      7.809566     8.075889     8.366010
# 2          38.801719     39.039014     39.323186    39.643848    39.894830
# 3          38.851444     40.197332     43.028332    44.389773    46.268621
# 4          24.594474     25.389297     27.041743    29.138285    30.998687
# ...              ...           ...           ...          ...          ...
# 393143           NaN           NaN           NaN          NaN          NaN
# 393144           NaN           NaN           NaN     5.400000          NaN
# 393145           NaN           NaN           NaN    33.700000          NaN
# 393146     59.700000     59.900000     60.100000    60.300000    60.500000
# 393147  15000.000000  13000.000000  10000.000000  8600.000000  7700.000000
#
#                2021  2022  Unnamed: 67
# 0         20.773627   NaN          NaN
# 1          8.684137   NaN          NaN
# 2         40.213891   NaN          NaN
# 3         48.103609   NaN          NaN
# 4         32.772690   NaN          NaN
# ...             ...   ...          ...
# 393143          NaN   NaN          NaN
# 393144          NaN   NaN          NaN
# 393145          NaN   NaN          NaN
# 393146    60.700000   NaN          NaN
# 393147  6800.000000   NaN          NaN
#
# [393148 rows x 68 columns]

# %%
### Check the first or last few rows.
## Check the first 5 rows.
df.head(5)
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2014       2015       2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  17.392349  17.892005  18.359993
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.720331   7.015917   7.281390
# 2   NaN   NaN   NaN   NaN   NaN  ...  38.184152  38.543180  38.801719
# 3   NaN   NaN   NaN   NaN   NaN  ...  31.859257  33.903515  38.851444
# 4   NaN   NaN   NaN   NaN   NaN  ...  17.623956  16.516633  24.594474
#
#         2017       2018       2019       2020       2021  2022  Unnamed: 67
# 0  18.795151  19.295176  19.788156  20.279599  20.773627   NaN          NaN
# 1   7.513673   7.809566   8.075889   8.366010   8.684137   NaN          NaN
# 2  39.039014  39.323186  39.643848  39.894830  40.213891   NaN          NaN
# 3  40.197332  43.028332  44.389773  46.268621  48.103609   NaN          NaN
# 4  25.389297  27.041743  29.138285  30.998687  32.772690   NaN          NaN
#
# [5 rows x 68 columns]

# %%
## Check the last 3 rows.
df.tail(3)
# Out:
#        Country Name Country Code  \
# 393145     Zimbabwe          ZWE
# 393146     Zimbabwe          ZWE
# 393147     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 393145  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 393146  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 393147  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#         1960  1961  1962  1963  1964  1965  ...     2014     2015     2016  \
# 393145   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN     32.4      NaN
# 393146   NaN   NaN   NaN   NaN   NaN   NaN  ...     59.4     59.5     59.7
# 393147   NaN   NaN   NaN   NaN   NaN   NaN  ...  19000.0  17000.0  15000.0
#
#            2017     2018    2019    2020    2021  2022  Unnamed: 67
# 393145      NaN      NaN    33.7     NaN     NaN   NaN          NaN
# 393146     59.9     60.1    60.3    60.5    60.7   NaN          NaN
# 393147  13000.0  10000.0  8600.0  7700.0  6800.0   NaN          NaN
#
# [3 rows x 68 columns]

# %% [markdown]
# # Q2 What is the type of the dataframe?
#
# ## In a Pandas DataFrame, there are several data types that you can encounter. The main types of data include:
#
# ### 1. Integer: Whole numbers, which can be of different sizes (e.g., int32, int64).
# ### 2. Float: Decimal numbers (e.g., float32, float64).
# ### 3. Object: Used for strings or mixed types. This is the default type for text data.
# ### 4. Boolean: Represents True or False values.
# ### 5. Datetime: Used for date and time data (e.g., datetime64).
# ### 6. Timedelta: Represents differences in time (duration).

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# Unnamed: 67       float64
# Length: 68, dtype: object

# %% [markdown]
# ### We may want to drop the last column named "Unnamed:67" later...

# %% [markdown]
# # Q3 How many columns and rows?

# %%
df.shape
### There are 393148 rows and 68 columns in this dataset.
# Out:
# (393148, 68)

# %% [markdown]
# # Q4 What are the country names in this dataset?

# %%
df["Country Name"].unique()
# Out:
# array(['Africa Eastern and Southern', 'Africa Western and Central',
#        'Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Middle East & North Africa',
#        'Middle East & North Africa (excluding high income)',
#        'Middle East & North Africa (IDA & IBRD countries)',
#        'Middle income', 'North America', 'Not classified', 'OECD members',
#        'Other small states', 'Pacific island small states',
#        'Post-demographic dividend', 'Pre-demographic dividend',
#        'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
#        'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
#        'World', 'Afghanistan', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Faroe Islands', 'Fiji',
#        'Finland', 'France', 'French Polynesia', 'Gabon', 'Gambia, The',
#        'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
#        'Grenada', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'Honduras', 'Hong Kong SAR, China', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo', 'Kuwait',
#        'Kyrgyz Republic', 'Lao PDR', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg',
#        'Macao SAR, China', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
#        'Mali', 'Malta', 'Marshall Islands', 'Mauritania', 'Mauritius',
#        'Mexico', 'Micronesia, Fed. Sts.', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
#        'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand',
#        'Nicaragua', 'Niger', 'Nigeria', 'North Macedonia',
#        'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
#        'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
#        'Spain', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'St. Vincent and the Grenadines',
#        'Sudan', 'Suriname', 'Sweden', 'Switzerland',
#        'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand',
#        'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
#        'Turkiye', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela, RB', 'Vietnam', 'Virgin Islands (U.S.)',
#        'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %% [markdown]
# # Q5 How many indicators and countries?

# %%
## Use nuique() to get the number of unique values.
df["Country Name"].nunique()
### There are 266 countries in the WDI dataset.
# Out:
# 266

# %%
df["Indicator Name"].nunique()
### WDI dataset provides 1478 indicators.
# Out:
# 1478

# %% [markdown]
# # Q6 How to drop and keep certain columns?

# %%
df.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2014       2015       2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  17.392349  17.892005  18.359993
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.720331   7.015917   7.281390
# 2   NaN   NaN   NaN   NaN   NaN  ...  38.184152  38.543180  38.801719
# 3   NaN   NaN   NaN   NaN   NaN  ...  31.859257  33.903515  38.851444
# 4   NaN   NaN   NaN   NaN   NaN  ...  17.623956  16.516633  24.594474
#
#         2017       2018       2019       2020       2021  2022  Unnamed: 67
# 0  18.795151  19.295176  19.788156  20.279599  20.773627   NaN          NaN
# 1   7.513673   7.809566   8.075889   8.366010   8.684137   NaN          NaN
# 2  39.039014  39.323186  39.643848  39.894830  40.213891   NaN          NaN
# 3  40.197332  43.028332  44.389773  46.268621  48.103609   NaN          NaN
# 4  25.389297  27.041743  29.138285  30.998687  32.772690   NaN          NaN
#
# [5 rows x 68 columns]

# %%
###Drop the last column
df_drop = df.drop(columns=["Unnamed: 67"])
df_drop.head(3)
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.914625  17.392349  17.892005
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.473301   6.720331   7.015917
# 2   NaN   NaN   NaN   NaN   NaN  ...  37.870347  38.184152  38.543180
#
#         2016       2017       2018       2019       2020       2021  2022
# 0  18.359993  18.795151  19.295176  19.788156  20.279599  20.773627   NaN
# 1   7.281390   7.513673   7.809566   8.075889   8.366010   8.684137   NaN
# 2  38.801719  39.039014  39.323186  39.643848  39.894830  40.213891   NaN
#
# [3 rows x 67 columns]

# %%
## Keep the certain columns
### For instance we want to keep the following three columns.
df_col = df[["Country Name", "Indicator Name", "2020"]]
df_col.head()
# Out:
#                   Country Name  \
# 0  Africa Eastern and Southern
# 1  Africa Eastern and Southern
# 2  Africa Eastern and Southern
# 3  Africa Eastern and Southern
# 4  Africa Eastern and Southern
#
#                                       Indicator Name       2020
# 0  Access to clean fuels and technologies for coo...  20.279599
# 1  Access to clean fuels and technologies for coo...   8.366010
# 2  Access to clean fuels and technologies for coo...  39.894830
# 3            Access to electricity (% of population)  46.268621
# 4  Access to electricity, rural (% of rural popul...  30.998687

# %% [markdown]
# # Q7 How to drop and keep certain rows?

# %%
## Delete specific rows based on the index
### In Pandas, an index is a fundamental component that serves as a unique identifier for each row in a DataFrame or Series.
### In this dataset, the index ranges from 0 to 393147. We can drop the first row by specifying index[0].
df_drop0 = df.drop(df.index[0])
df_drop0
# Out:
#                        Country Name Country Code  \
# 1       Africa Eastern and Southern          AFE
# 2       Africa Eastern and Southern          AFE
# 3       Africa Eastern and Southern          AFE
# 4       Africa Eastern and Southern          AFE
# 5       Africa Eastern and Southern          AFE
# ...                             ...          ...
# 393143                     Zimbabwe          ZWE
# 393144                     Zimbabwe          ZWE
# 393145                     Zimbabwe          ZWE
# 393146                     Zimbabwe          ZWE
# 393147                     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 1       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3                 Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4       Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 5       Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# ...                                                   ...                ...
# 393143  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 393144  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 393145  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 393146  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 393147  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#         1960  1961  1962  1963  1964  1965  ...          2014          2015  \
# 1        NaN   NaN   NaN   NaN   NaN   NaN  ...      6.720331      7.015917
# 2        NaN   NaN   NaN   NaN   NaN   NaN  ...     38.184152     38.543180
# 3        NaN   NaN   NaN   NaN   NaN   NaN  ...     31.859257     33.903515
# 4        NaN   NaN   NaN   NaN   NaN   NaN  ...     17.623956     16.516633
# 5        NaN   NaN   NaN   NaN   NaN   NaN  ...     65.998898     67.022332
# ...      ...   ...   ...   ...   ...   ...  ...           ...           ...
# 393143   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN     14.500000
# 393144   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN      3.700000
# 393145   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN     32.400000
# 393146   NaN   NaN   NaN   NaN   NaN   NaN  ...     59.400000     59.500000
# 393147   NaN   NaN   NaN   NaN   NaN   NaN  ...  19000.000000  17000.000000
#
#                 2016          2017          2018         2019         2020  \
# 1           7.281390      7.513673      7.809566     8.075889     8.366010
# 2          38.801719     39.039014     39.323186    39.643848    39.894830
# 3          38.851444     40.197332     43.028332    44.389773    46.268621
# 4          24.594474     25.389297     27.041743    29.138285    30.998687
# 5          68.907404     70.663096     71.565376    72.611685    74.129923
# ...              ...           ...           ...          ...          ...
# 393143           NaN           NaN           NaN          NaN          NaN
# 393144           NaN           NaN           NaN     5.400000          NaN
# 393145           NaN           NaN           NaN    33.700000          NaN
# 393146     59.700000     59.900000     60.100000    60.300000    60.500000
# 393147  15000.000000  13000.000000  10000.000000  8600.000000  7700.000000
#
#                2021  2022  Unnamed: 67
# 1          8.684137   NaN          NaN
# 2         40.213891   NaN          NaN
# 3         48.103609   NaN          NaN
# 4         32.772690   NaN          NaN
# 5         75.559174   NaN          NaN
# ...             ...   ...          ...
# 393143          NaN   NaN          NaN
# 393144          NaN   NaN          NaN
# 393145          NaN   NaN          NaN
# 393146    60.700000   NaN          NaN
# 393147  6800.000000   NaN          NaN
#
# [393147 rows x 68 columns]

# %%
## Keep specific rows based on certain conditions
### Choose the country named United States
df_US = df[df["Country Name"] == "United States"]

df_US
# Out:
#          Country Name Country Code  \
# 376890  United States          USA
# 376891  United States          USA
# 376892  United States          USA
# 376893  United States          USA
# 376894  United States          USA
# ...               ...          ...
# 378363  United States          USA
# 378364  United States          USA
# 378365  United States          USA
# 378366  United States          USA
# 378367  United States          USA
#
#                                            Indicator Name     Indicator Code  \
# 376890  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 376891  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 376892  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 376893            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 376894  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...                                                   ...                ...
# 378363  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 378364  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 378365  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 378366  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 378367  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#         1960  1961  1962  1963  1964  1965  ...    2014    2015    2016  \
# 376890   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# 376891   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# 376892   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# 376893   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# 376894   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# ...      ...   ...   ...   ...   ...   ...  ...     ...     ...     ...
# 378363   NaN   NaN   NaN   NaN   NaN   NaN  ...     NaN     NaN     NaN
# 378364   NaN   NaN   NaN   NaN   NaN   NaN  ...     NaN     NaN     NaN
# 378365   NaN   NaN   NaN   NaN   NaN   NaN  ...     NaN     NaN     NaN
# 378366   NaN   NaN   NaN   NaN   NaN   NaN  ...    22.8    22.7    22.5
# 378367   NaN   NaN   NaN   NaN   NaN   NaN  ...  7600.0  7300.0  6800.0
#
#           2017    2018    2019   2020   2021  2022  Unnamed: 67
# 376890   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# 376891   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# 376892   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# 376893   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# 376894   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# ...        ...     ...     ...    ...    ...   ...          ...
# 378363     NaN     NaN     NaN    NaN    NaN   NaN          NaN
# 378364     NaN     NaN     NaN    NaN    NaN   NaN          NaN
# 378365     NaN     NaN     NaN    NaN    NaN   NaN          NaN
# 378366    22.4    22.3    22.3   22.2   22.1   NaN          NaN
# 378367  6500.0  6400.0  6100.0    NaN    NaN   NaN          NaN
#
# [1478 rows x 68 columns]

# %%
## How about two conditions? Use "&" to add more conditions.
df_US_gdp = df[
    (df["Country Name"] == "United States")
    & (df["Indicator Name"] == "GDP per capita (current US$)")
]

df_US_gdp
# Out:
#          Country Name Country Code                Indicator Name  \
# 377370  United States          USA  GDP per capita (current US$)
#
#         Indicator Code         1960         1961         1962         1963  \
# 377370  NY.GDP.PCAP.CD  3007.123445  3066.562869  3243.843078  3374.515171
#
#                1964        1965  ...          2014          2015  \
# 377370  3573.941185  3827.52711  ...  55123.849787  56762.729452
#
#                 2016          2017          2018          2019          2020  \
# 377370  57866.744934  59907.754261  62823.309438  65120.394663  63528.634303
#
#                 2021          2022  Unnamed: 67
# 377370  70219.472454  76398.591742          NaN
#
# [1 rows x 68 columns]

# %% [markdown]
# # Q8 How to reshape data?
# ## Pandas provides multiple methods like melt(), pivot_table(), stack(), unstack() ,etc to reshape data.
# ### https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html

# %% [markdown]
# ## 1) melt(). This function is used to transform or reshape data from a wide format to a long format. It essentially unpivots the DataFrame, converting columns into rows.
# ### https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.melt.html#pandas.DataFrame.melt
#
# ### Key parameters:
# #### id_vars: A list or tuple of column names to use as identifier variables. These columns will remain as columns in the resulting DataFrame.
# #### value_vars: A list or tuple of column names to unpivot. These columns will be converted into a single column in the resulting DataFrame.
# #### var_name: The name to use for the column that contains the variable names (default is 'variable').
# #### value_name: The name to use for the column that contains the values (default is 'value').

# %%
df_gdp_melt = (
    df_US_gdp.drop(columns=["Unnamed: 67"])
    .melt(
        id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
        value_name="GDP per capita (current US$)",
        var_name="Year",
    )
    .drop(columns=["Country Code", "Indicator Code"])
)
df_gdp_melt

### By using the melt() function, the DataFrame df_gdp_melt is now clean and in panel format. It contains unique values for Country Name and Year.
# Out:
#      Country Name                Indicator Name  Year  \
# 0   United States  GDP per capita (current US$)  1960
# 1   United States  GDP per capita (current US$)  1961
# 2   United States  GDP per capita (current US$)  1962
# 3   United States  GDP per capita (current US$)  1963
# 4   United States  GDP per capita (current US$)  1964
# ..            ...                           ...   ...
# 58  United States  GDP per capita (current US$)  2018
# 59  United States  GDP per capita (current US$)  2019
# 60  United States  GDP per capita (current US$)  2020
# 61  United States  GDP per capita (current US$)  2021
# 62  United States  GDP per capita (current US$)  2022
#
#     GDP per capita (current US$)
# 0                    3007.123445
# 1                    3066.562869
# 2                    3243.843078
# 3                    3374.515171
# 4                    3573.941185
# ..                           ...
# 58                  62823.309438
# 59                  65120.394663
# 60                  63528.634303
# 61                  70219.472454
# 62                  76398.591742
#
# [63 rows x 4 columns]

# %% [markdown]
# ### In the last example, we used df_US_gdp, which contains only GDP per capita (current US$) for the United States. It could become more complicated if we add more variables. For instance, we can use df_US, which contains all the variables provided by the WDI.

# %%
df_US
# Out:
#          Country Name Country Code  \
# 376890  United States          USA
# 376891  United States          USA
# 376892  United States          USA
# 376893  United States          USA
# 376894  United States          USA
# ...               ...          ...
# 378363  United States          USA
# 378364  United States          USA
# 378365  United States          USA
# 378366  United States          USA
# 378367  United States          USA
#
#                                            Indicator Name     Indicator Code  \
# 376890  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 376891  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 376892  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 376893            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 376894  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...                                                   ...                ...
# 378363  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 378364  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 378365  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 378366  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 378367  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#         1960  1961  1962  1963  1964  1965  ...    2014    2015    2016  \
# 376890   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# 376891   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# 376892   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# 376893   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# 376894   NaN   NaN   NaN   NaN   NaN   NaN  ...   100.0   100.0   100.0
# ...      ...   ...   ...   ...   ...   ...  ...     ...     ...     ...
# 378363   NaN   NaN   NaN   NaN   NaN   NaN  ...     NaN     NaN     NaN
# 378364   NaN   NaN   NaN   NaN   NaN   NaN  ...     NaN     NaN     NaN
# 378365   NaN   NaN   NaN   NaN   NaN   NaN  ...     NaN     NaN     NaN
# 378366   NaN   NaN   NaN   NaN   NaN   NaN  ...    22.8    22.7    22.5
# 378367   NaN   NaN   NaN   NaN   NaN   NaN  ...  7600.0  7300.0  6800.0
#
#           2017    2018    2019   2020   2021  2022  Unnamed: 67
# 376890   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# 376891   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# 376892   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# 376893   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# 376894   100.0   100.0   100.0  100.0  100.0   NaN          NaN
# ...        ...     ...     ...    ...    ...   ...          ...
# 378363     NaN     NaN     NaN    NaN    NaN   NaN          NaN
# 378364     NaN     NaN     NaN    NaN    NaN   NaN          NaN
# 378365     NaN     NaN     NaN    NaN    NaN   NaN          NaN
# 378366    22.4    22.3    22.3   22.2   22.1   NaN          NaN
# 378367  6500.0  6400.0  6100.0    NaN    NaN   NaN          NaN
#
# [1478 rows x 68 columns]

# %%
df_melt = (
    df_US.drop(columns=["Unnamed: 67"])
    .melt(
        id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
        var_name="Year",
    )
    .drop(columns=["Country Code","Indicator Code"])
)

### df_melt isn't a panel data we wanted, we want the Indicator Name listed by columns.
df_melt
# Out:
#         Country Name                                     Indicator Name  Year  \
# 0      United States  Access to clean fuels and technologies for coo...  1960
# 1      United States  Access to clean fuels and technologies for coo...  1960
# 2      United States  Access to clean fuels and technologies for coo...  1960
# 3      United States            Access to electricity (% of population)  1960
# 4      United States  Access to electricity, rural (% of rural popul...  1960
# ...              ...                                                ...   ...
# 93109  United States  Women who believe a husband is justified in be...  2022
# 93110  United States  Women who were first married by age 15 (% of w...  2022
# 93111  United States  Women who were first married by age 18 (% of w...  2022
# 93112  United States  Women's share of population ages 15+ living wi...  2022
# 93113  United States  Young people (ages 15-24) newly infected with HIV  2022
#
#        value
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 93109    NaN
# 93110    NaN
# 93111    NaN
# 93112    NaN
# 93113    NaN
#
# [93114 rows x 4 columns]

# %% [markdown]
# ## 2） pivot_table(). This function is used to create a pivot table from a DataFrame. It allows you to summarize and aggregate data based on one or more columns, providing insights into the relationships between different variables.
# ### https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html#pandas.pivot_table
#
# ### key parameters:
#
# #### data: The DataFrame to be used for creating the pivot table.
# #### values: The column(s) to aggregate.
# #### index: The column(s) to be used as the index of the resulting pivot table.
# #### columns: The column(s) to be used as the columns of the resulting pivot table.
# #### aggfunc: The aggregation function(s) to apply to the values. It can be a single function, a list of functions, or a dictionary mapping columns to functions.
# #### fill_value: The value to replace missing values with (default is None).

# %%
df_pivottable = df_melt.pivot_table(
    values="value",
    index=["Country Name", "Year"],
    columns="Indicator Name",
)

df_pivottable.head()

### Now the variables in the Indicator Name are listed as columns. However, it looks strange due to the multilevel index.
# Out:
# Indicator Name      Access to clean fuels and technologies for cooking (% of population)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Access to electricity (% of population)  \
# Country Name  Year
# United States 1960                                      NaN
#               1961                                      NaN
#               1962                                      NaN
#               1963                                      NaN
#               1964                                      NaN
#
# Indicator Name      Access to electricity, rural (% of rural population)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Access to electricity, urban (% of urban population)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Account ownership at a financial institution or with a mobile-money-service provider, male (% of population ages 15+)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Account ownership at a financial institution or with a mobile-money-service provider, older adults (% of population ages 25+)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      ...  \
# Country Name  Year  ...
# United States 1960  ...
#               1961  ...
#               1962  ...
#               1963  ...
#               1964  ...
#
# Indicator Name      Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Vulnerable employment, male (% of male employment) (modeled ILO estimate)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Women Business and the Law Index Score (scale 1-100)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Women's share of population ages 15+ living with HIV (%)  \
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# Indicator Name      Young people (ages 15-24) newly infected with HIV
# Country Name  Year
# United States 1960                                                NaN
#               1961                                                NaN
#               1962                                                NaN
#               1963                                                NaN
#               1964                                                NaN
#
# [5 rows x 1163 columns]

# %%
# How to get rid of multilevel index after using pivottable?

# After using reset_index, we can get rid of the multilevel index.
WDI_US_0 = df_pivottable.reset_index()

WDI_US_0
# Out:
# Indicator Name   Country Name  Year  \
# 0               United States  1960
# 1               United States  1961
# 2               United States  1962
# 3               United States  1963
# 4               United States  1964
# ..                        ...   ...
# 58              United States  2018
# 59              United States  2019
# 60              United States  2020
# 61              United States  2021
# 62              United States  2022
#
# Indicator Name  Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                          100.0
# 59                                                          100.0
# 60                                                          100.0
# 61                                                          100.0
# 62                                                            NaN
#
# Indicator Name  Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                          100.0
# 59                                                          100.0
# 60                                                          100.0
# 61                                                          100.0
# 62                                                            NaN
#
# Indicator Name  Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                          100.0
# 59                                                          100.0
# 60                                                          100.0
# 61                                                          100.0
# 62                                                            NaN
#
# Indicator Name  Access to electricity (% of population)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ..                                                  ...
# 58                                                100.0
# 59                                                100.0
# 60                                                100.0
# 61                                                100.0
# 62                                                  NaN
#
# Indicator Name  Access to electricity, rural (% of rural population)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                          100.0
# 59                                                          100.0
# 60                                                          100.0
# 61                                                          100.0
# 62                                                            NaN
#
# Indicator Name  Access to electricity, urban (% of urban population)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                          100.0
# 59                                                          100.0
# 60                                                          100.0
# 61                                                          100.0
# 62                                                            NaN
#
# Indicator Name  Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                            NaN
# 59                                                            NaN
# 60                                                            NaN
# 61                                                          94.95
# 62                                                            NaN
#
# Indicator Name  Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                            NaN
# 59                                                            NaN
# 60                                                            NaN
# 61                                                          96.79
# 62                                                            NaN
#
# Indicator Name  ...  \
# 0               ...
# 1               ...
# 2               ...
# 3               ...
# 4               ...
# ..              ...
# 58              ...
# 59              ...
# 60              ...
# 61              ...
# 62              ...
#
# Indicator Name  Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                       3.536253
# 59                                                       3.474749
# 60                                                       3.735224
# 61                                                       3.895916
# 62                                                            NaN
#
# Indicator Name  Vulnerable employment, male (% of male employment) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                       4.583925
# 59                                                       4.418259
# 60                                                       4.354936
# 61                                                       4.605415
# 62                                                            NaN
#
# Indicator Name  Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                       4.099700
# 59                                                       3.981149
# 60                                                       4.068956
# 61                                                       4.276413
# 62                                                            NaN
#
# Indicator Name  Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                       94.82776
# 59                                                       94.91877
# 60                                                       94.53311
# 61                                                       94.29491
# 62                                                            NaN
#
# Indicator Name  Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                       92.76611
# 59                                                       93.03202
# 60                                                       92.97375
# 61                                                       92.61697
# 62                                                            NaN
#
# Indicator Name  Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                       93.71900
# 59                                                       93.90617
# 60                                                       93.69337
# 61                                                       93.39504
# 62                                                            NaN
#
# Indicator Name  Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                      43.839207
# 59                                                      44.845071
# 60                                                      43.603848
# 61                                                            NaN
# 62                                                            NaN
#
# Indicator Name  Women Business and the Law Index Score (scale 1-100)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                          91.25
# 59                                                          91.25
# 60                                                          91.25
# 61                                                          91.25
# 62                                                          91.25
#
# Indicator Name  Women's share of population ages 15+ living with HIV (%)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                           22.3
# 59                                                           22.3
# 60                                                           22.2
# 61                                                           22.1
# 62                                                            NaN
#
# Indicator Name  Young people (ages 15-24) newly infected with HIV
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ..                                                            ...
# 58                                                         6400.0
# 59                                                         6100.0
# 60                                                            NaN
# 61                                                            NaN
# 62                                                            NaN
#
# [63 rows x 1165 columns]

# %%
# However, in the new index, the first row named 'Indicator Name' should be empty. Therefore, we use rename_axis to reset the index.
WDI_US = WDI_US_0.rename_axis("", axis=1)

WDI_US.head()

# Now, WDI_US is the panel data we wanted!
# Out:
#     Country Name  Year  \
# 0  United States  1960
# 1  United States  1961
# 2  United States  1962
# 3  United States  1963
# 4  United States  1964
#
#    Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to electricity (% of population)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Access to electricity, rural (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to electricity, urban (% of urban population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Vulnerable employment, male (% of male employment) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women Business and the Law Index Score (scale 1-100)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women's share of population ages 15+ living with HIV (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Young people (ages 15-24) newly infected with HIV
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 1165 columns]

# %%
### Recheck the data types and find that the column 'Year' is of type object. 
### However, an object type cannot be used in mathematical calculations or sorting.
WDI_US.dtypes
# Out:
# Country Name                                                                                         object
# Year                                                                                                 object
# Access to clean fuels and technologies for cooking (% of population)                                float64
# Access to clean fuels and technologies for cooking, rural (% of rural population)                   float64
# Access to clean fuels and technologies for cooking, urban (% of urban population)                   float64
#                                                                                                      ...
# Wage and salaried workers, total (% of total employment) (modeled ILO estimate)                     float64
# Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)    float64
# Women Business and the Law Index Score (scale 1-100)                                                float64
# Women's share of population ages 15+ living with HIV (%)                                            float64
# Young people (ages 15-24) newly infected with HIV                                                   float64
# Length: 1165, dtype: object

# %%
### So, the 'Year' column needs to be converted to an integer.
WDI_US["Year"] = WDI_US['Year'].astype(int)

WDI_US.dtypes
# Out:
# Country Name                                                                                         object
# Year                                                                                                  int64
# Access to clean fuels and technologies for cooking (% of population)                                float64
# Access to clean fuels and technologies for cooking, rural (% of rural population)                   float64
# Access to clean fuels and technologies for cooking, urban (% of urban population)                   float64
#                                                                                                      ...
# Wage and salaried workers, total (% of total employment) (modeled ILO estimate)                     float64
# Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)    float64
# Women Business and the Law Index Score (scale 1-100)                                                float64
# Women's share of population ages 15+ living with HIV (%)                                            float64
# Young people (ages 15-24) newly infected with HIV                                                   float64
# Length: 1165, dtype: object

# %% [markdown]
# # Q9 How to export data to csv?

# %%
WDI_US.to_csv(
    '/home/aistudio/data/WDI_US.csv', index=False
)

### By setting index=False, we drop the index from the CSV file. You can set it to True if you want to keep the index.

# %% [markdown]
# # Q10 How many missing values for each variable?
# ### isna(): This method checks each element in the WDI_US DataFrame for missing values (NaN). It returns a DataFrame of the same shape, where each element is either True (if the original value is NaN) or False (if the original value is not NaN).
# ### sum(): After checking for missing values, this method aggregates the results. By default, it sums along the columns (i.e., it counts the number of True values for each column). The result is a Series where the index is the column names of WDI_US, and the values are the counts of missing values (NaN) in each column.
# ### sort_values(ascending=True): This sorts the resulting Series by the count of missing values in ascending order. This means that columns with fewer missing values will appear first, and columns with more missing values will appear later.

# %%
WDI_US.isna()
# Out:
#     Country Name   Year  \
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False
# ..           ...    ...
# 58         False  False
# 59         False  False
# 60         False  False
# 61         False  False
# 62         False  False
#
#     Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Access to electricity (% of population)  \
# 0                                      True
# 1                                      True
# 2                                      True
# 3                                      True
# 4                                      True
# ..                                      ...
# 58                                    False
# 59                                    False
# 60                                    False
# 61                                    False
# 62                                     True
#
#     Access to electricity, rural (% of rural population)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Access to electricity, urban (% of urban population)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                               True
# 59                                               True
# 60                                               True
# 61                                              False
# 62                                               True
#
#     Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                               True
# 59                                               True
# 60                                               True
# 61                                              False
# 62                                               True
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 58  ...
# 59  ...
# 60  ...
# 61  ...
# 62  ...
#
#     Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Vulnerable employment, male (% of male employment) (modeled ILO estimate)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                               True
# 62                                               True
#
#     Women Business and the Law Index Score (scale 1-100)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                              False
#
#     Women's share of population ages 15+ living with HIV (%)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                              False
# 61                                              False
# 62                                               True
#
#     Young people (ages 15-24) newly infected with HIV
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 58                                              False
# 59                                              False
# 60                                               True
# 61                                               True
# 62                                               True
#
# [63 rows x 1165 columns]

# %%
WDI_US.isna().sum()
# Out:
# Country Name                                                                                         0
# Year                                                                                                 0
# Access to clean fuels and technologies for cooking (% of population)                                41
# Access to clean fuels and technologies for cooking, rural (% of rural population)                   41
# Access to clean fuels and technologies for cooking, urban (% of urban population)                   41
#                                                                                                     ..
# Wage and salaried workers, total (% of total employment) (modeled ILO estimate)                     32
# Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)    22
# Women Business and the Law Index Score (scale 1-100)                                                10
# Women's share of population ages 15+ living with HIV (%)                                            31
# Young people (ages 15-24) newly infected with HIV                                                   53
# Length: 1165, dtype: int64

# %%
isna_data = WDI_US.isna().sum().sort_values(ascending=True)
isna_data
# Out:
# Population ages 70-74, male (% of male population)                           0
# Population ages 65 and above, total                                          0
# Population ages 65-69, female (% of female population)                       0
# Population ages 65-69, male (% of male population)                           0
# Population ages 70-74, female (% of female population)                       0
#                                                                             ..
# Trained teachers in secondary education (% of total teachers)               62
# Number of surgical procedures (per 100,000 population)                      62
# Trained teachers in upper secondary education, male (% of male teachers)    62
# Trained teachers in primary education, male (% of male teachers)            62
# Trained teachers in primary education, female (% of female teachers)        62
# Length: 1165, dtype: int64

# %% [markdown]
# # Now we obtain the data for the United States and all variables provided by the WDI dataset, reshape the data into panel format, and count the number of missing values for all variables.
